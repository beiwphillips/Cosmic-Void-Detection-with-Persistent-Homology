# %%
import numpy as np
import bisect

from matplotlib import pyplot as plt

# %%
from pixel3d import Pixel3D

# %%
from topologicalunionfind import TopologicalUnionFind

# %%
from voidsfinding import VoidsFinding

# %% [markdown]
# ### Two Lonely Voids

# %%
binary = np.loadtxt('../mock/two_lonely_voids.txt')
binary.shape
# Out:
# (86400,)

# %%
binary.

# %%
cube_shape = (24, 24, 150)

# %%
cube = binary.reshape(cube_shape)
cube.shape
# Out:
# (24, 24, 150)

# %% [markdown]
# ### Plotting

# %%
plt.imshow(cube.sum(axis=2))
plt.colorbar()
plt.show()

# %% [markdown]
# ### diagonal = False

# %%
reverse = True
diagonal = False

# %%
vf = VoidsFinding(cube, reverse, diagonal)

# %%
vf.findVoidsUF()

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceDiagramUF()

# %%
d = vf.getHistory()

# %%
import json
with open('../mock/two_lonely_voids.json', 'w') as outfile:  
    json.dump(d, outfile)

# %% [markdown]
# ### Stochastic Field

# %%
binary = np.fromfile('../mock/stochastic.bin')
binary.shape
# Out:
# (86400,)

# %%
cube_shape = (24, 24, 150)

# %%
cube = binary.reshape(cube_shape)
cube.shape
# Out:
# (24, 24, 150)

# %% [markdown]
# ### Plotting

# %%
cube.max()
# Out:
# 3.677666127443602

# %%
cube.min()
# Out:
# -2.9117548878888613

# %%
plt.imshow(cube.sum(axis=0))
plt.colorbar()
plt.show()

# %% [markdown]
# ### diagonal = False

# %%
reverse = True
diagonal = False

# %%
vf = VoidsFinding(cube, reverse, diagonal)

# %%
vf.findVoidsUF()

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceDiagramUF()

# %%
d = vf.getHistory()

# %%
import json
with open('../mock/stochastic.json', 'w') as outfile:  
    json.dump(d, outfile)
