# %%
import numpy as np
import bisect

from matplotlib import pyplot as plt

# %%
from pixel2d import Pixel2D

# %%
from topologicalunionfind import TopologicalUnionFind

# %%
from voidsfinding import VoidsFinding

# %% [markdown]
# ### Reading Slice

# %%
binary = np.fromfile('../cube/map.bin')
binary.shape
# Out:
# (87464,)

# %%
cube_shape = (26, 29, 116)

# %%
cube = binary.reshape(cube_shape)
cube.shape
# Out:
# (26, 29, 116)

# %%
aslice = cube[:,:,60]
aslice.shape
# Out:
# (26, 29)

# %%
plt.imshow(aslice)
plt.colorbar()
plt.show()

# %%
bslice = (aslice == 0) * 1
bslice.shape
# Out:
# (26, 29)

# %%
plt.imshow(bslice)
plt.colorbar()
plt.show()

# %% [markdown]
# ### diagonal = False

# %%
reverse = True
diagonal = False

# %%
vf = VoidsFinding(aslice, reverse, diagonal)

# %%
vf.findVoidsUF()
vf.findVoidsPH('./PerseusMac', 'slice_d0')
# Out:
# CompletedProcess(args=['./PerseusMac', 'nmfsimtop', 'slice_d0.txt', 'slice_d0'], returncode=0)

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceBarcodesPH()

# %%
vf.plotPersistenceDiagramUF()

# %%
vf.plotPersistenceDiagramPH()

# %% [markdown]
# ### diagonal = True

# %%
reverse = True
diagonal = True

# %%
vf = VoidsFinding(aslice, reverse, diagonal)

# %%
vf.findVoidsUF()
vf.findVoidsPH('./PerseusMac', 'slice_d1')
# Out:
# CompletedProcess(args=['./PerseusMac', 'nmfsimtop', 'slice_d1.txt', 'slice_d1'], returncode=0)

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceBarcodesPH()

# %%
vf.plotPersistenceDiagramUF()

# %%
vf.plotPersistenceDiagramPH()
