# %%
import numpy as np
import bisect

from matplotlib import pyplot as plt

# %%
from pixel3d import Pixel3D

# %%
from topologicalunionfind import TopologicalUnionFind

# %%
from voidsfinding import VoidsFinding

# %% [markdown]
# ### Reading Original Cube

# %%
prefix = '../simulation/v6.0.0_original_'

# %%
binary = np.fromfile(prefix+'map.bin')

# %%
with open(prefix+'void.cfg') as cfg:
    lines = cfg.readlines()
    nx = int(lines[4].split()[-1])
    ny = int(lines[5].split()[-1])
    nz = int(lines[6].split()[-1])

# %%
cube = binary.reshape(nx, ny, nz)

# %%
vf = VoidsFinding(cube, reverse=True, diagonal=False)

# %%
vf.findVoidsUF()

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceDiagramUF()

# %% [markdown]
# ### Reading Shuffled Cube

# %%
prefix = '../simulationshuffled/v6.0.0_shuffle_'

# %%
binary = np.fromfile(prefix+'map.bin')

# %%
with open(prefix+'void.cfg') as cfg:
    lines = cfg.readlines()
    nx = int(lines[4].split()[-1])
    ny = int(lines[5].split()[-1])
    nz = int(lines[6].split()[-1])

# %%
cube = binary.reshape(nx, ny, nz)

# %%
vf = VoidsFinding(cube, reverse=True, diagonal=False)

# %%
vf.findVoidsUF()

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceDiagramUF()
