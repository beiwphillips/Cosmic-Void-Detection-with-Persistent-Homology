# %%
import numpy as np
import bisect

from matplotlib import pyplot as plt

# %%
from pixel2d import Pixel2D

# %%
from topologicalunionfind import TopologicalUnionFind

# %%
from voidsfinding import VoidsFinding

# %% [markdown]
# ### Reading Slice

# %%
aslice = np.array([[1,3,8], [5,7,6], [9,4,2]])
aslice
# Out:
# array([[1, 3, 8],
#        [5, 7, 6],
#        [9, 4, 2]])

# %%
plt.imshow(aslice)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Reverse = False, Diagonal = False

# %%
reverse = False
diagonal = False

# %%
vf = VoidsFinding(aslice, reverse, diagonal)
vf

# %%
vf.findVoidsUF()
vf.findVoidsPH('./perseusMac', 'toy2d_r0d0')
# Out:
# CompletedProcess(args=['./perseusMac', 'nmfsimtop', 'toy2d_r0d0.txt', 'toy2d_r0d0'], returncode=0)

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceBarcodesPH()

# %%
vf.plotPersistenceDiagramUF()

# %%
vf.plotPersistenceDiagramPH()

# %% [markdown]
# ### Reverse = False, Diagonal = True

# %%
reverse = False
diagonal = True

# %%
vf = VoidsFinding(aslice, reverse, diagonal)
vf

# %%
vf.findVoidsUF()
vf.findVoidsPH('./perseusMac', 'toy2d_r0d1')
# Out:
# CompletedProcess(args=['./perseusMac', 'nmfsimtop', 'toy2d_r0d1.txt', 'toy2d_r0d1'], returncode=0)

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceBarcodesPH()

# %%
vf.plotPersistenceDiagramUF()

# %%
vf.plotPersistenceDiagramPH()

# %% [markdown]
# ### Reverse = True, Diagonal = False

# %%
reverse = True
diagonal = False

# %%
vf = VoidsFinding(aslice, reverse, diagonal)
vf

# %%
vf.findVoidsUF()
vf.findVoidsPH('./perseusMac', 'toy2d_r1d0')
# Out:
# CompletedProcess(args=['./perseusMac', 'nmfsimtop', 'toy2d_r1d0.txt', 'toy2d_r1d0'], returncode=0)

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceBarcodesPH()

# %%
vf.plotPersistenceDiagramUF()

# %%
vf.plotPersistenceDiagramPH()

# %%
vf.getHistory()
# Out:
# {'bar-0': {'birth': 9,
#   'death': -inf,
#   'history': {9: [(2, 0)],
#    5: [(1, 0), (0, 2), (1, 2), (1, 1)],
#    4: [(2, 1)],
#    3: [(0, 1)],
#    2: [(2, 2)],
#    1: [(0, 0)]}},
#  'bar-1': {'birth': 8,
#   'death': 5,
#   'history': {8: [(0, 2)], 6: [(1, 2), (1, 1)]}},
#  'bar-2': {'birth': 7, 'death': 6, 'history': {7: [(1, 1)]}}}

# %% [markdown]
# ### Reverse = True, Diagonal = True

# %%
reverse = True
diagonal = True

# %%
vf = VoidsFinding(aslice, reverse, diagonal)
vf

# %%
vf.findVoidsUF()
vf.findVoidsPH('./perseusMac', 'toy2d_r1d1')
# Out:
# CompletedProcess(args=['./perseusMac', 'nmfsimtop', 'toy2d_r1d1.txt', 'toy2d_r1d1'], returncode=0)

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceBarcodesPH()

# %%
vf.plotPersistenceDiagramUF()

# %%
vf.plotPersistenceDiagramPH()

# %%
vf.getHistory()
# Out:
# {'bar-0': {'birth': 9,
#   'death': -inf,
#   'history': {9: [(2, 0)],
#    7: [(0, 2), (1, 1)],
#    6: [(1, 2)],
#    5: [(1, 0)],
#    4: [(2, 1)],
#    3: [(0, 1)],
#    2: [(2, 2)],
#    1: [(0, 0)]}},
#  'bar-1': {'birth': 8, 'death': 7, 'history': {8: [(0, 2)], 7: [(1, 1)]}}}
