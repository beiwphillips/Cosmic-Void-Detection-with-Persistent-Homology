# %%
import numpy as np
import bisect

from matplotlib import pyplot as plt

# %%
from pixel3d import Pixel3D

# %%
from topologicalunionfind import TopologicalUnionFind

# %%
from voidsfinding import VoidsFinding

# %% [markdown]
# ### Reading Slice

# %%
cube = np.array([[[3, 6, 9],
                  [3, 1, 5],
                  [3, 4, 3]],

                 [[8, 7, 4],
                  [8, 4, 5],
                  [4, 7, 5]],

                 [[7, 8, 2],
                  [2, 1, 5],
                  [6, 6, 7]]])

# %%
fig1 = plt.subplot(1, 3, 1)
fig1.imshow(cube[0])
fig2 = plt.subplot(1, 3, 2)
fig2.imshow(cube[1])
fig3 = plt.subplot(1, 3, 3)
fig3.imshow(cube[2])
plt.show()

# %% [markdown]
# ### Reverse = False, Diagonal = False

# %%
reverse = False
diagonal = False

# %%
vf = VoidsFinding(cube, reverse, diagonal)
vf

# %%
vf.findVoidsUF()
vf.findVoidsPH('./PerseusMac', 'toy3d_r0d0')
# Out:
# CompletedProcess(args=['./PerseusMac', 'nmfsimtop', 'toy3d_r0d0.txt', 'toy3d_r0d0'], returncode=0)

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceBarcodesPH()

# %%
vf.plotPersistenceDiagramUF()

# %%
vf.plotPersistenceDiagramPH()

# %% [markdown]
# ### Reverse = False, Diagonal = True

# %%
reverse = False
diagonal = True

# %%
vf = VoidsFinding(cube, reverse, diagonal)
vf

# %%
vf.findVoidsUF()
vf.findVoidsPH('./perseusMac', 'toy3d_r0d1')
# Out:
# CompletedProcess(args=['./perseusMac', 'nmfsimtop', 'toy3d_r0d1.txt', 'toy3d_r0d1'], returncode=0)

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceBarcodesPH()

# %%
vf.plotPersistenceDiagramUF()

# %%
vf.plotPersistenceDiagramPH()

# %% [markdown]
# ### Reverse = True, Diagonal = False

# %%
reverse = True
diagonal = False

# %%
vf = VoidsFinding(cube, reverse, diagonal)
vf

# %%
vf.findVoidsUF()
vf.findVoidsPH('./PerseusMac', 'toy3d_r1d0')
# Out:
# CompletedProcess(args=['./PerseusMac', 'nmfsimtop', 'toy3d_r1d0.txt', 'toy3d_r1d0'], returncode=0)

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceBarcodesPH()

# %%
vf.plotPersistenceDiagramUF()

# %%
vf.plotPersistenceDiagramPH()

# %% [markdown]
# ### Reverse = True, Diagonal = True

# %%
reverse = True
diagonal = True

# %%
vf = VoidsFinding(cube, reverse, diagonal)
vf

# %%
vf.findVoidsUF()
vf.findVoidsPH('./perseusMac', 'toy3d_r1d1')
# Out:
# CompletedProcess(args=['./perseusMac', 'nmfsimtop', 'toy3d_r1d1.txt', 'toy3d_r1d1'], returncode=0)

# %%
vf.plotPersistenceBarcodesUF()

# %%
vf.plotPersistenceBarcodesPH()

# %%
vf.plotPersistenceDiagramUF()

# %%
vf.plotPersistenceDiagramPH()
