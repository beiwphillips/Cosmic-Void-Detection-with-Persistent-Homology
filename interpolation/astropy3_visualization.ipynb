# %%
import numpy as np
# %matplotlib notebook

# %%
m = np.fromfile('map.bin')

# %%
m.shape
# Out:
# (35226,)

# %%
gs  = (103, 114, 3)

# %%
m_grid = m.reshape(gs)

# %%
m_grid.shape
# Out:
# (103, 114, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(m_grid[:, :, 1])
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(m_grid[:, 20, 0])
# Out:
# <img src="data:image/png;base64,..." width="640">
